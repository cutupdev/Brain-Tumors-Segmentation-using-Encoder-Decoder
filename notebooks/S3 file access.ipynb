# %%
import s3fs

# %%
fs = s3fs.S3FileSystem(anon=False, key='AKIAVAW4TJF2RXGKDVNP', secret='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')

# %%
fs.ls('brats-data/brats-data/MICCAI_BraTS2020_TrainingData')
# Out:
# ['brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011',
#  'brats-data/brats-data/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012',
# ...

# %%
import boto3

# %%
 s3 = boto3.resource('s3')

# %%
my_bucket = s3.Bucket(name='brats-data')

# %%
# for my_bucket_object in my_bucket.objects.all():
#     print(my_bucket_object)

# %%
# make new bucket for preprocessed data
s3.create_bucket(Bucket='my-bucket')
